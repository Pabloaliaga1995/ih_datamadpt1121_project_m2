# %%
import sqlalchemy
import pandas as pd
import sqlite3 as sql

# %%
database = 'db/diamonds_m2.db'
connection = sql.connect(database)

# %%
query = '''SELECT tr.index_id, c.clarity, cl.color, ct.cut, dm.depth, dm.'table', dm.x, dm.y, dm.z, tr.price, ci.city, tr.carat
FROM diamonds_properties pr
   INNER JOIN diamonds_clarity c ON pr.clarity_id = c.clarity_id 
   INNER JOIN diamonds_color cl on pr.color_id = cl.color_id 
   INNER JOIN diamonds_cut ct on pr.cut_id = ct.cut_id 
   INNER JOIN diamonds_dimensions dm on pr.index_id = dm.index_id
   INNER JOIN diamonds_transactional tr on pr.index_id = tr.index_id
   INNER JOIN diamonds_city ci on tr.city_id = ci.city_id'''

# %%
diamonds = pd.read_sql_query(query,connection)
diamonds
# Out:
#                                                 index_id clarity color  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...     VS2     J
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...     VS2     H
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...     VS1     G
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...     SI1     D
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...     SI1     G
# ...                                                  ...     ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...     VS1     G
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...     SI2     F
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...     SI1     H
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...     VS1     J
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...     SI1     I
#
#              cut  depth  table     x     y     z  price       city  carat
# 0        Premium   62.4   58.0  6.83  6.79  4.25   4268      Dubai   1.21
# 1      Very Good   63.0   57.0  4.35  4.38  2.75    505   Kimberly   0.32
# 2           Fair   65.5   55.0  5.62  5.53  3.65   2686  Las Vegas   0.71
# 3           Good   63.8   56.0  4.68  4.72  3.00    738   Kimberly   0.41
# 4          Ideal   60.5   59.0  6.55  6.51  3.95   4882      Dubai   1.02
# ...          ...    ...    ...   ...   ...   ...    ...        ...    ...
# 40450      Ideal   62.7   57.0  7.10  7.04  4.43  10070    Antwerp   1.34
# 40451       Good   57.1   60.0  8.31  8.25  4.73  12615     Madrid   2.02
# 40452      Ideal   62.7   56.0  6.37  6.42  4.01   5457   Kimberly   1.01
# 40453      Ideal   61.9   54.3  4.45  4.47  2.76    456   Kimberly   0.33
# 40454      Ideal   62.0   58.0  6.83  6.88  4.25   6232     London   1.24
#
# [40455 rows x 12 columns]

# %%
diamonds1 = diamonds.to_csv("db/diamonds.csv")
